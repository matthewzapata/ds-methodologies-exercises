# %% [markdown]
# ## Iris Data

# %%
import pandas as pd
import env
from acquire import get_iris_data, get_titanic_data
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
iris_df = get_iris_data()
# Out:
# Use this as dbc to help get your SQL data: Engine(mysql+pymysql://ada_665:***@157.230.209.171/iris_db)
# Don't forget to assign to a df

# %%
iris_df.head()
# Out:
#    measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0               1           5.1          3.5           1.4          0.2
# 1               2           4.9          3.0           1.4          0.2
# 2               3           4.7          3.2           1.3          0.2
# 3               4           4.6          3.1           1.5          0.2
# 4               5           5.0          3.6           1.4          0.2
#
#    species_id species_name
# 0           1       setosa
# 1           1       setosa
# 2           1       setosa
# 3           1       setosa
# 4           1       setosa

# %%
iris_df.drop(['measurement_id', 'species_id'], axis=1, inplace=True)

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species_name
# 0           5.1          3.5           1.4          0.2       setosa
# 1           4.9          3.0           1.4          0.2       setosa
# 2           4.7          3.2           1.3          0.2       setosa
# 3           4.6          3.1           1.5          0.2       setosa
# 4           5.0          3.6           1.4          0.2       setosa

# %%
iris_df.rename(columns={'species_name':'species'}, inplace=True)
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
species = LabelEncoder()

# %%
species.fit(iris_df.species)
# Out:
# LabelEncoder()

# %%
iris_df['species_transformed'] = species.transform(iris_df.species)

# %%
iris_df.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 86            6.7          3.1           4.7          1.5  versicolor
# 117           7.7          3.8           6.7          2.2   virginica
# 5             5.4          3.9           1.7          0.4      setosa
# 62            6.0          2.2           4.0          1.0  versicolor
# 8             4.4          2.9           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 124           6.7          3.3           5.7          2.1   virginica
# 15            5.7          4.4           1.5          0.4      setosa
# 75            6.6          3.0           4.4          1.4  versicolor
# 2             4.7          3.2           1.3          0.2      setosa
#
#      species_transformed
# 86                     1
# 117                    2
# 5                      0
# 62                     1
# 8                      0
# 1                      0
# ...

# %% [markdown]
# `inverse_transform` will transform the data back into its previous state.

# %%
species.inverse_transform(iris_df.species_transformed)
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
# ...

# %%
def drop_columns(df):
    df.drop(['measurement_id', 'species_id'], axis=1, inplace=True)
    return df
    
def iris_rename(df):
    df.rename(columns={'species_name':'species'}, inplace=True)
    return df
    
def iris_label_encoder(df):
    species = LabelEncoder()
    species.fit(df.species)
    df['species_transformed'] = species.transform(df.species)
    return df
    
def prep_iris(df):
    drop_columns(df)
    iris_rename(df)
    iris_label_encoder(df)
    return df

# %%
prep_iris(get_iris_data()).head()
# Out:
# Use this as dbc to help get your SQL data: Engine(mysql+pymysql://ada_665:***@157.230.209.171/iris_db)
# Don't forget to assign to a df
#    sepal_length  sepal_width  petal_length  petal_width species  \
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
#    species_transformed
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %% [markdown]
# ## Titanic Data

# %%
titanic_df = get_titanic_data()
# Out:
# Use this as dbc to help get your SQL data: Engine(mysql+pymysql://ada_665:***@157.230.209.171/titanic_db)
# Don't forget to assign to a df

# %%
titanic_df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0
# 2        S  Third  None  Southampton      1
# 3        S  First     C  Southampton      0
# 4        S  Third  None  Southampton      1

# %%
titanic_df.isna().sum()
# Out:
# passenger_id      0
# survived          0
# pclass            0
# sex               0
# age             177
# sibsp             0
# parch             0
# fare              0
# embarked          2
# class             0
# deck            688
# embark_town       2
# alone             0
# dtype: int64

# %%
titanic_df.embark_town.isna().sum()
# Out:
# 2

# %%
titanic_df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0
# 2        S  Third  None  Southampton      1
# 3        S  First     C  Southampton      0
# 4        S  Third  None  Southampton      1

# %%
titanic_df.embark_town.fillna('Other', inplace=True)

# %%
titanic_df.isna().sum()
# Out:
# passenger_id      0
# survived          0
# pclass            0
# sex               0
# age             177
# sibsp             0
# parch             0
# fare              0
# embarked          2
# class             0
# deck            688
# embark_town       0
# alone             0
# dtype: int64

# %%
titanic_df.embarked.head()
# Out:
# 0    S
# 1    C
# 2    S
# 3    S
# 4    S
# Name: embarked, dtype: object

# %%
titanic_df.embarked.fillna('O', inplace=True)

# %%
titanic_df.isna().sum()
# Out:
# passenger_id      0
# survived          0
# pclass            0
# sex               0
# age             177
# sibsp             0
# parch             0
# fare              0
# embarked          0
# class             0
# deck            688
# embark_town       0
# alone             0
# dtype: int64

# %%
titanic_df.drop(['deck'], axis=1, inplace=True)
titanic_df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  embark_town  alone
# 0        S  Third  Southampton      0
# 1        C  First    Cherbourg      0
# 2        S  Third  Southampton      1
# 3        S  First  Southampton      0
# 4        S  Third  Southampton      1

# %%
titanic_df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0
# 2        S  Third  None  Southampton      1
# 3        S  First     C  Southampton      0
# 4        S  Third  None  Southampton      1

# %%
embarked_t = LabelEncoder()

# %%
embarked_t.fit(titanic_df.embarked)
# Out:
# LabelEncoder()

# %%
titanic_df.embarked.unique()
# Out:
# array(['S', 'C', 'Q', 'O'], dtype=object)

# %%
titanic_df['embarked_transform'] = embarked_t.transform(titanic_df.embarked)

# %%
titanic_df.sample(10)
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 173           173         0       3    male  21.0      0      0   7.9250
# 836           836         0       3    male  21.0      0      0   8.6625
# 264           264         0       3  female   NaN      0      0   7.7500
# 366           366         1       1  female  60.0      1      0  75.2500
# 761           761         0       3    male  41.0      0      0   7.1250
# 427           427         1       2  female  19.0      0      0  26.0000
# 178           178         0       2    male  30.0      0      0  13.0000
# 793           793         0       1    male   NaN      0      0  30.6958
# 747           747         1       2  female  30.0      0      0  13.0000
# 574           574         0       3    male  16.0      0      0   8.0500
#
#     embarked   class  embark_town  alone  embarked_transform
# 173        S   Third  Southampton      1                   3
# ...

# %%
X = titanic_df.drop(['passenger_id', 'survived'], axis=1)
y = titanic_df[['survived']]

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.80, random_state=10)

train = pd.concat((X_train, y_train), axis=1)
test = pd.concat((X_test, y_test), axis=1)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
scaler = MinMaxScaler()
scaler.fit(train[['fare', 'age']])
train[['fare', 'age']] = scaler.transform(train[['fare', 'age']])

# %%
train.head()
# Out:
#      pclass     sex       age  sibsp  parch      fare embarked   class  \
# 57        3    male  0.352852      0      0  0.014110        C   Third
# 717       2  female  0.334004      0      0  0.020495        S  Second
# 431       3  female       NaN      1      0  0.031425        S   Third
# 633       1    male       NaN      0      0  0.000000        S   First
# 163       3    male  0.208344      0      0  0.016908        S   Third
#
#      embark_town  alone  embarked_transform  survived
# 57     Cherbourg      1                   0         0
# 717  Southampton      1                   3         1
# 431  Southampton      0                   3         1
# 633  Southampton      1                   3         0
# 163  Southampton      1                   3         0

# %% [markdown]
# Before performing the standardization, the range of fare was relatively large compared to the other variables. In this case, I think it is beneficial. It wouldn't be beneficial if the variables are in similar units or already close to 0.

# %%
def titanic_fillna(df):
    df.embark_town.fillna('Other', inplace=True)
    df.embarked.fillna('O', inplace=True)
    print('fill')
    return df

def titanic_drop(df):
    df.drop(['deck'], axis=1, inplace=True)
    print('drop')
    return df

def titanic_encode_embarked(df):
    embarked_t = LabelEncoder()
    embarked_t.fit(df.embarked)
    df['embarked_transform'] = embarked_t.transform(df.embarked)
    print('encode')
    return df

def titanic_split(df):
    global train, test, X_train, X_test, y_train, y_test, X, y
    X = df.drop(['passenger_id', 'survived'], axis=1)
    y = df[['survived']]
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.80, random_state=10)
    train = pd.concat((X_train, y_train), axis=1)
    test = pd.concat((X_test, y_test), axis=1)
    print('split')
    return train

def titanic_min_max_age_fare(train):
    scaler = MinMaxScaler()
    scaler.fit(train[['fare', 'age']])
    train[['fare', 'age']] = scaler.transform(train[['fare', 'age']])
    print('standard')
    return train
    
    
def prep_titanic(df):
    titanic_fillna(df)
    titanic_drop(df)
    titanic_encode_embarked(df)
    titanic_split(df)
    titanic_min_max_age_fare(train)
    return df

# %%
from prepare import prep_titanic
prep_titanic(get_titanic_data())
# Out:
# Use this as dbc to help get your SQL data: Engine(mysql+pymysql://ada_665:***@157.230.209.171/titanic_db)
# Don't forget to assign to a df
# fill
# drop
# encode
# split
# standard
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
#      passenger_id  survived  pclass     sex   age  sibsp  parch      fare  \
# 0               0         0       3    male  22.0      1      0    7.2500
# 1               1         1       1  female  38.0      1      0   71.2833
# 2               2         1       3  female  26.0      0      0    7.9250
# 3               3         1       1  female  35.0      1      0   53.1000
# 4               4         0       3    male  35.0      0      0    8.0500
# 5               5         0       3    male   NaN      0      0    8.4583
# ...

# %%
train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5e6a15ce28a5> in <module>
# ----> 1 train.shape
#
# NameError: name 'train' is not defined

# %%
test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8ae592785626> in <module>
# ----> 1 test.shape
#
# NameError: name 'test' is not defined

# %%
X.shape
# Out:
# (891, 11)
