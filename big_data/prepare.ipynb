# %% [markdown]
# # Prepare

# %%
from pyspark.sql import SparkSession
import pandas as pd
import pyspark.sql.functions as F
from pyspark.sql.functions import col, expr
import pandas as pd

# %% [markdown]
# ## Part 1
# 1. Read the case.csv file from the 311 call data into a Spark DataFrame.
# 1. How old is the latest (in terms of days past SLA) currently open issue? How long has the oldest (in terms of days since opened) currently opened issue been open?
# 1. How many Stray Animal cases are there?
# 1. How many service requests that are assigned to the Field Operations department (dept_division) are not classified as "Officer Standby" request type (service_request_type)?
# 1. Create a new DataFrame without any information related to dates or location.
# 1. Read dept.csv into a Spark DataFrame. Inspect the dept_name column. Replace the missing values with "other".

# %% [markdown]
# ##### Creating Spark Session object

# %%
spark = SparkSession.builder.master('local').appName('transform1').getOrCreate()

# %% [markdown]
# ##### Reading in csv with spark

# %%
df = spark.read.csv('sa311/case.csv', header=True, inferSchema=True)

# %%
df.show(3)
# Out:
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |   case_id|case_opened_date|case_closed_date|SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|   SLA_days|case_status|source_id|     request_address|council_district|
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |1014127332|     1/1/18 0:42|    1/1/18 12:29|9/26/20 0:42|       NO| -998.5087616000001|        YES|Field Operations|        Stray Animal|      999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|
# |1014127333|     1/1/18 0:46|     1/3/18 8:11| 1/5/18 8:30|       NO|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|
# |1014127334|     1/1/18 0:48|     1/2/18 7:57| 1/5/18 8:30|       NO|       -3.022337963|        YES|     Storm Water|Removal Of Obstru...|4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# only showing top 3 rows

# %%
df.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: string (nullable = true)
#  |-- case_closed_date: string (nullable = true)
#  |-- SLA_due_date: string (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %% [markdown]
# ##### How old is the latest (in terms of days past SLA) currently open issue?

# %%
(df.select(F.to_date(col('SLA_due_date'),format='M/d/y H:m').alias('SLA_date'),
           F.current_date().alias('today'),
           col('case_opened_date').alias('date_opened'),
           col('case_closed').alias('closed'))
 .where(col('closed') == 'NO')
 .withColumn('date_diff_SLA_2_today', F.datediff(col('SLA_date'), col('today')))
 .sort(col('date_opened'), ascending=False)
 .show(1))
# Out:
# +----------+----------+------------+------+---------------------+
# |  SLA_date|     today| date_opened|closed|date_diff_SLA_2_today|
# +----------+----------+------------+------+---------------------+
# |2017-11-14|2019-05-17|9/9/17 11:43|    NO|                 -549|
# +----------+----------+------------+------+---------------------+
# only showing top 1 row

# %% [markdown]
# ##### How long has the oldest (in terms of days since opened) currently opened issue been open?

# %%
(df.select(F.to_date(col('SLA_due_date'), format='M/d/y H:m').alias('SLA_date'),
           F.current_date().alias('today'),
           F.to_date(col('case_opened_date'), format='M/d/y H:m').alias('date_opened'),
           col('case_closed').alias('closed'))
 .where(col('closed') == 'NO')
 .withColumn('date_diff_open_2_today', F.datediff(col('date_opened'), col('today')))
 .sort(col('date_opened'))
 .select(col('date_diff_open_2_today'))
 .show(1))
# Out:
# +----------------------+
# |date_diff_open_2_today|
# +----------------------+
# |                  -866|
# +----------------------+
# only showing top 1 row

# %% [markdown]
# ##### How many Stray Animal cases are there?

# %%
df.show(3)
# Out:
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |   case_id|case_opened_date|case_closed_date|SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|   SLA_days|case_status|source_id|     request_address|council_district|
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |1014127332|     1/1/18 0:42|    1/1/18 12:29|9/26/20 0:42|       NO| -998.5087616000001|        YES|Field Operations|        Stray Animal|      999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|
# |1014127333|     1/1/18 0:46|     1/3/18 8:11| 1/5/18 8:30|       NO|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|
# |1014127334|     1/1/18 0:48|     1/2/18 7:57| 1/5/18 8:30|       NO|       -3.022337963|        YES|     Storm Water|Removal Of Obstru...|4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# only showing top 3 rows

# %%
df.select('*').where(col('service_request_type') == "Stray Animal").count()
# Out:
# 26760

# %% [markdown]
# ##### How many service requests that are assigned to the Field Operations department (dept_division) are not classified as "Officer Standby" request type (service_request_type)?

# %%
(df.select(col('dept_division'), col('service_request_type'))
 .where(col('dept_division') == 'Field Operations')
 .where(col('service_request_type') != 'Officer Standby')
 .count())
# Out:
# 113902

# %% [markdown]
# ##### Create a new DataFrame without any information related to dates or location.

# %%
df.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: string (nullable = true)
#  |-- case_closed_date: string (nullable = true)
#  |-- SLA_due_date: string (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %%
new_df = df.select('case_id', 'case_late', 'num_days_late', 'case_closed', 'dept_division',
                   'service_request_type', 'SLA_days', 'case_status', 'source_id', 'council_district')

# %% [markdown]
# ### Read dept.csv into a Spark DataFrame. Inspect the dept_name column.
# Replace the missing values with "other"

# %%
dept_df = spark.read.csv('sa311/dept.csv', header=True, inferSchema=True)
dept_df.show(5)
# Out:
# +--------------------+--------------------+----------------------+-------------------+
# |       dept_division|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +--------------------+--------------------+----------------------+-------------------+
# |     311 Call Center|    Customer Service|      Customer Service|                YES|
# |               Brush|Solid Waste Manag...|           Solid Waste|                YES|
# |     Clean and Green|Parks and Recreation|    Parks & Recreation|                YES|
# |Clean and Green N...|Parks and Recreation|    Parks & Recreation|                YES|
# |    Code Enforcement|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# +--------------------+--------------------+----------------------+-------------------+
# only showing top 5 rows

# %%
dept_df.na.fill({'dept_name' : 'other'}).show(8)
# Out:
# +--------------------+--------------------+----------------------+-------------------+
# |       dept_division|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +--------------------+--------------------+----------------------+-------------------+
# |     311 Call Center|    Customer Service|      Customer Service|                YES|
# |               Brush|Solid Waste Manag...|           Solid Waste|                YES|
# |     Clean and Green|Parks and Recreation|    Parks & Recreation|                YES|
# |Clean and Green N...|Parks and Recreation|    Parks & Recreation|                YES|
# |    Code Enforcement|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement ...|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement ...|               other|  DSD/Code Enforcement|                YES|
# |   Dangerous Premise|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# +--------------------+--------------------+----------------------+-------------------+
# only showing top 8 rows

# %% [markdown]
# Useful to see all nulls per column.

# %%
dept_df.select([F.count(F.when(F.isnull(c), c)).alias(c) for c in dept_df.columns]).show()
# Out:
# +-------------+---------+----------------------+-------------------+
# |dept_division|dept_name|standardized_dept_name|dept_subject_to_SLA|
# +-------------+---------+----------------------+-------------------+
# |            0|        1|                     0|                  0|
# +-------------+---------+----------------------+-------------------+

# %% [markdown]
# ## Part 2
# 1. Convert the council_district column to a string column.
# 1. Extract the year from the case_closed_date column.
# 1. Convert num_days_late from days to hours in new columns num_hours_late.
# 1. Convert the case_late column to a boolean column.
# 1. Convert the SLA_days columns to a double column.
# 1. Pull it all together

# %%
df.show(3)
# Out:
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |   case_id|case_opened_date|case_closed_date|SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|   SLA_days|case_status|source_id|     request_address|council_district|
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |1014127332|     1/1/18 0:42|    1/1/18 12:29|9/26/20 0:42|       NO| -998.5087616000001|        YES|Field Operations|        Stray Animal|      999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|
# |1014127333|     1/1/18 0:46|     1/3/18 8:11| 1/5/18 8:30|       NO|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|
# |1014127334|     1/1/18 0:48|     1/2/18 7:57| 1/5/18 8:30|       NO|       -3.022337963|        YES|     Storm Water|Removal Of Obstru...|4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# only showing top 3 rows

# %% [markdown]
# ##### Convert the council_district column to a string column.

# %%
df.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: string (nullable = true)
#  |-- case_closed_date: string (nullable = true)
#  |-- SLA_due_date: string (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %%
df.select(col('council_district').cast('string')).printSchema()
# Out:
# root
#  |-- council_district: string (nullable = true)

# %% [markdown]
# ##### Extract the year from the case_closed_date column.

# %%
(df.select(col('case_closed_date'), 
          F.regexp_extract(col('case_closed_date'), '\d+/\d+/(\d+)', 1).alias('year'))
.show(5))
# Out:
# +----------------+----+
# |case_closed_date|year|
# +----------------+----+
# |    1/1/18 12:29|  18|
# |     1/3/18 8:11|  18|
# |     1/2/18 7:57|  18|
# |     1/2/18 8:13|  18|
# |    1/1/18 13:29|  18|
# +----------------+----+
# only showing top 5 rows

# %% [markdown]
# ##### Convert num_days_late from days to hours in new columns num_hours_late.

# %%
df.select(col('num_days_late')).withColumn('num_hours_late', F.round(df.num_days_late * 24, 2)).show(5)
# Out:
# +-------------------+--------------+
# |      num_days_late|num_hours_late|
# +-------------------+--------------+
# | -998.5087616000001|     -23964.21|
# |-2.0126041669999997|         -48.3|
# |       -3.022337963|        -72.54|
# |       -15.01148148|       -360.28|
# |0.37216435200000003|          8.93|
# +-------------------+--------------+
# only showing top 5 rows

# %% [markdown]
# ##### Convert the case_late column to a boolean column.

# %%
df.select(col('case_late'), col('num_days_late')).withColumn('case_late', col('case_late') == 'YES').show(5)
# Out:
# +---------+-------------------+
# |case_late|      num_days_late|
# +---------+-------------------+
# |    false| -998.5087616000001|
# |    false|-2.0126041669999997|
# |    false|       -3.022337963|
# |    false|       -15.01148148|
# |     true|0.37216435200000003|
# +---------+-------------------+
# only showing top 5 rows

# %% [markdown]
# ##### Convert the SLA_days columns to a double column.
# It already is a double column, but might have needed to import the 'double' type to cast it if it wasn't.

# %% [markdown]
# ##### Pull it all together

# %%
(df.select(col('council_district').cast('string'), 
           col('case_closed_date'), 
           F.regexp_extract(col('case_closed_date'), '\d+/\d+/(\d+)', 1).alias('year'), 
           col('case_late'), 
           col('num_days_late'))
 .withColumn('num_hours_late', F.round(df.num_days_late * 24, 2))
 .withColumn('case_late_bool', col('case_late') == 'YES').show(5))
# Out:
# +----------------+----------------+----+---------+-------------------+--------------+--------------+
# |council_district|case_closed_date|year|case_late|      num_days_late|num_hours_late|case_late_bool|
# +----------------+----------------+----+---------+-------------------+--------------+--------------+
# |               5|    1/1/18 12:29|  18|       NO| -998.5087616000001|     -23964.21|         false|
# |               3|     1/3/18 8:11|  18|       NO|-2.0126041669999997|         -48.3|         false|
# |               3|     1/2/18 7:57|  18|       NO|       -3.022337963|        -72.54|         false|
# |               3|     1/2/18 8:13|  18|       NO|       -15.01148148|       -360.28|         false|
# |               7|    1/1/18 13:29|  18|      YES|0.37216435200000003|          8.93|          true|
# +----------------+----------------+----+---------+-------------------+--------------+--------------+
# only showing top 5 rows

# %% [markdown]
# ## Part 3
# 1. Create a DataFrame with all combinations of council_district and service_request_type (regardless of whether the combination is observed in the data).
# 1. Join the case data with the source and department data.
# 1. Are there any cases that do not have a request source?

# %% [markdown]
# ##### Create a DataFrame with all combinations of council_district and service_request_type
# (regardless of whether the combination is observed in the data).

# %%
df.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: string (nullable = true)
#  |-- case_closed_date: string (nullable = true)
#  |-- SLA_due_date: string (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %%
a = (df.select(col('council_district')).dropDuplicates())

b = (df.select(col('service_request_type')).dropDuplicates())

b.crossJoin(a).orderBy(['service_request_type', 'council_district']).show(truncate=False)
# Out:
# +------------------------+----------------+
# |service_request_type    |council_district|
# +------------------------+----------------+
# |"Vacant Lot-City (12"")"|0               |
# |"Vacant Lot-City (12"")"|1               |
# |"Vacant Lot-City (12"")"|2               |
# |"Vacant Lot-City (12"")"|3               |
# |"Vacant Lot-City (12"")"|4               |
# |"Vacant Lot-City (12"")"|5               |
# |"Vacant Lot-City (12"")"|6               |
# |"Vacant Lot-City (12"")"|7               |
# |"Vacant Lot-City (12"")"|8               |
# |"Vacant Lot-City (12"")"|9               |
# |"Vacant Lot-City (12"")"|10              |
# |"Vacant Lot-City (48"")"|0               |
# |"Vacant Lot-City (48"")"|1               |
# |"Vacant Lot-City (48"")"|2               |
# |"Vacant Lot-City (48"")"|3               |
# |"Vacant Lot-City (48"")"|4               |
# |"Vacant Lot-City (48"")"|5               |
# |"Vacant Lot-City (48"")"|6               |
# |"Vacant Lot-City (48"")"|7               |
# |"Vacant Lot-City (48"")"|8               |
# +------------------------+----------------+
# only showing top 20 rows

# %% [markdown]
# ##### Join the case data with the source and department data.

# %%
source_df = spark.read.csv('sa311/source.csv', header=True, inferSchema=True)

# %%
source_df.show(3)
# Out:
# +---------+----------------+
# |source_id| source_username|
# +---------+----------------+
# |   100137|Merlene Blodgett|
# |   103582|     Carmen Cura|
# |   106463| Richard Sanchez|
# +---------+----------------+
# only showing top 3 rows

# %%
df.show(3)
# Out:
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |   case_id|case_opened_date|case_closed_date|SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|   SLA_days|case_status|source_id|     request_address|council_district|
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |1014127332|     1/1/18 0:42|    1/1/18 12:29|9/26/20 0:42|       NO| -998.5087616000001|        YES|Field Operations|        Stray Animal|      999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|
# |1014127333|     1/1/18 0:46|     1/3/18 8:11| 1/5/18 8:30|       NO|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|
# |1014127334|     1/1/18 0:48|     1/2/18 7:57| 1/5/18 8:30|       NO|       -3.022337963|        YES|     Storm Water|Removal Of Obstru...|4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# only showing top 3 rows

# %%
dept_df.show(3)
# Out:
# +---------------+--------------------+----------------------+-------------------+
# |  dept_division|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +---------------+--------------------+----------------------+-------------------+
# |311 Call Center|    Customer Service|      Customer Service|                YES|
# |          Brush|Solid Waste Manag...|           Solid Waste|                YES|
# |Clean and Green|Parks and Recreation|    Parks & Recreation|                YES|
# +---------------+--------------------+----------------------+-------------------+
# only showing top 3 rows

# %%
(df.join(source_df, 
         df.source_id == source_df.source_id, 
         'left')
 .join(dept_df, 
       df.dept_division == dept_df.dept_division, 
       'left')).limit(100).toPandas()
# Out:
#        case_id case_opened_date case_closed_date   SLA_due_date case_late  \
# 0   1014127332      1/1/18 0:42     1/1/18 12:29   9/26/20 0:42        NO
# 1   1014127333      1/1/18 0:46      1/3/18 8:11    1/5/18 8:30        NO
# 2   1014127334      1/1/18 0:48      1/2/18 7:57    1/5/18 8:30        NO
# 3   1014127335      1/1/18 1:29      1/2/18 8:13   1/17/18 8:30        NO
# 4   1014127336      1/1/18 1:34     1/1/18 13:29    1/1/18 4:34       YES
# 5   1014127337      1/1/18 6:28     1/1/18 14:38   1/31/18 8:30        NO
# 6   1014127338      1/1/18 6:57     1/2/18 15:32   1/17/18 8:30        NO
# 7   1014127339      1/1/18 6:58     1/2/18 15:32   1/17/18 8:30        NO
# 8   1014127340      1/1/18 6:58     1/2/18 15:32   1/17/18 8:30        NO
# 9   1014127341      1/1/18 6:59     1/2/18 15:32   1/17/18 8:30        NO
# 10  1014127342      1/1/18 7:00     1/2/18 15:32   1/17/18 8:30        NO
# 11  1014127343      1/1/18 7:02     1/2/18 15:32   1/17/18 8:30        NO
# 12  1014127344      1/1/18 7:02     1/2/18 15:33   1/17/18 8:30        NO
# 13  1014127345      1/1/18 7:03     1/2/18 15:32   1/17/18 8:30        NO
# 14  1014127346      1/1/18 7:04     1/2/18 15:33   1/17/18 8:30        NO
# 15  1014127347      1/1/18 7:04     1/2/18 15:33   1/17/18 8:30        NO
# 16  1014127348      1/1/18 7:05     1/2/18 15:33   1/17/18 8:30        NO
# 17  1014127349      1/1/18 7:06     1/2/18 15:33   1/17/18 8:30        NO
# 18  1014127350      1/1/18 7:06     1/2/18 15:33   1/17/18 8:30        NO
# 19  1014127351      1/1/18 7:07     1/2/18 15:33   1/17/18 8:30        NO
# 20  1014127352      1/1/18 7:08     1/2/18 15:34   1/17/18 8:30        NO
# 21  1014127353      1/1/18 7:08     1/2/18 15:34   1/17/18 8:30        NO
# 22  1014127354      1/1/18 7:09     1/2/18 15:34   1/17/18 8:30        NO
# 23  1014127355      1/1/18 7:10     1/2/18 15:35   1/17/18 8:30        NO
# 24  1014127356      1/1/18 7:10     1/2/18 15:35   1/17/18 8:30        NO
# 25  1014127357      1/1/18 7:11     1/2/18 15:35   1/17/18 8:30        NO
# 26  1014127358      1/1/18 7:12     1/2/18 15:35   1/17/18 8:30        NO
# 27  1014127359      1/1/18 7:12     1/2/18 15:35   1/17/18 8:30        NO
# 28  1014127360      1/1/18 7:13     1/2/18 15:35   1/17/18 8:30        NO
# 29  1014127361      1/1/18 7:13     1/2/18 15:35   1/17/18 8:30        NO
# ..         ...              ...              ...            ...       ...
# 70  1014127424     1/1/18 10:44     1/1/18 12:43  9/26/20 10:44        NO
# 71  1014127427     1/1/18 10:48     1/1/18 15:15   1/1/18 22:48        NO
# 72  1014127428     1/1/18 10:52     1/1/18 11:53  9/26/20 10:52        NO
# 73  1014127429     1/1/18 10:53     1/3/18 18:43   1/1/18 22:53       YES
# 74  1014127431     1/1/18 10:56    2/21/18 20:06   1/6/18 10:56       YES
# 75  1014127432     1/1/18 10:56    2/21/18 20:06   1/6/18 10:56       YES
# 76  1014127434     1/1/18 11:02     1/1/18 16:50   1/6/18 11:02        NO
# 77  1014127436     1/1/18 11:04     1/2/18 13:42   2/14/18 8:30        NO
# 78  1014127438     1/1/18 11:06    3/19/18 20:33   1/6/18 11:06       YES
# 79  1014127439     1/1/18 11:09      1/2/18 7:27   1/3/18 11:09        NO
# 80  1014127440     1/1/18 11:11     1/1/18 11:53  9/26/20 11:11        NO
# 81  1014127441     1/1/18 11:13    4/25/18 16:48   1/1/18 23:13       YES
# 82  1014127442     1/1/18 11:18      1/2/18 7:29   1/3/18 11:18        NO
# 83  1014127444     1/1/18 11:23     1/1/18 11:39   1/1/18 14:23        NO
# 84  1014127445     1/1/18 11:25      1/2/18 7:30   1/3/18 11:25        NO
# 85  1014127446     1/1/18 11:27     1/3/18 17:08   1/6/18 11:27        NO
# 86  1014127449     1/1/18 11:37    3/26/18 14:47   1/6/18 11:37       YES
# 87  1014127450     1/1/18 11:38     1/9/18 22:28   1/6/18 11:38       YES
# 88  1014127451     1/1/18 11:42    3/20/18 15:33   1/6/18 11:42       YES
# 89  1014127452     1/1/18 11:46      1/3/18 7:55   1/1/18 23:46       YES
# 90  1014127453     1/1/18 11:46     1/1/18 12:26  9/26/20 11:46        NO
# 91  1014127454     1/1/18 11:50    3/15/18 12:28   1/6/18 11:50       YES
# 92  1014127455     1/1/18 11:58     1/1/18 12:26  9/26/20 11:58        NO
# 93  1014127456     1/1/18 12:04     1/2/18 15:28   1/17/18 8:30        NO
# 94  1014127457     1/1/18 12:10     1/1/18 12:43    1/3/18 8:30        NO
# 95  1014127460     1/1/18 12:12     1/2/18 16:54    1/4/18 8:30        NO
# 96  1014127463     1/1/18 12:21    3/19/18 21:17   1/6/18 12:21       YES
# 97  1014127465     1/1/18 12:22      1/2/18 9:48    1/4/18 8:30        NO
# 98  1014127467     1/1/18 12:28     1/1/18 12:44  9/26/20 12:28        NO
# 99  1014127468     1/1/18 12:31     1/3/18 12:09    1/2/18 0:31       YES
#
#     num_days_late case_closed       dept_division  \
# 0     -998.508762         YES    Field Operations
# 1       -2.012604         YES         Storm Water
# 2       -3.022338         YES         Storm Water
# 3      -15.011481         YES    Code Enforcement
# 4        0.372164         YES    Field Operations
# 5      -29.743981         YES             Signals
# 6      -14.706736         YES    Code Enforcement
# 7      -14.706620         YES    Code Enforcement
# 8      -14.706620         YES    Code Enforcement
# 9      -14.706493         YES    Code Enforcement
# 10     -14.706493         YES    Code Enforcement
# 11     -14.706366         YES    Code Enforcement
# 12     -14.706250         YES    Code Enforcement
# 13     -14.706366         YES    Code Enforcement
# 14     -14.706238         YES    Code Enforcement
# 15     -14.705891         YES    Code Enforcement
# 16     -14.706007         YES    Code Enforcement
# 17     -14.705764         YES    Code Enforcement
# 18     -14.705764         YES    Code Enforcement
# 19     -14.705648         YES    Code Enforcement
# 20     -14.705405         YES    Code Enforcement
# 21     -14.705521         YES    Code Enforcement
# 22     -14.704942         YES    Code Enforcement
# 23     -14.704815         YES    Code Enforcement
# 24     -14.704815         YES    Code Enforcement
# 25     -14.704699         YES    Code Enforcement
# 26     -14.704699         YES    Code Enforcement
# 27     -14.704572         YES    Code Enforcement
# 28     -14.704572         YES    Code Enforcement
# 29     -14.704340         YES    Code Enforcement
# ..            ...         ...                 ...
# 70    -998.917998         YES    Field Operations
# 71      -0.314826         YES    Field Operations
# 72    -998.957616         YES    Field Operations
# 73       1.826227         YES    Field Operations
# 74      46.381921         YES    Field Operations
# 75      46.381759         YES    Field Operations
# 76      -4.758808         YES    Field Operations
# 77     -42.782894         YES             Streets
# 78      72.394039         YES    Field Operations
# 79      -1.154387         YES       Miscellaneous
# 80    -998.970787         YES    Field Operations
# 81     113.733009         YES    Field Operations
# 82      -1.158924         YES       Miscellaneous
# 83      -0.114120         YES    Field Operations
# 84      -1.163646         YES       Miscellaneous
# 85      -2.763333         YES    Field Operations
# 86      79.131574         YES    Field Operations
# 87       3.450984         YES    Field Operations
# 88      73.160556         YES    Field Operations
# 89       1.339676         YES    Field Operations
# 90    -998.972257         YES    Field Operations
# 91      68.025856         YES    Field Operations
# 92    -998.980637         YES    Field Operations
# 93     -14.709178         YES    Code Enforcement
# 94      -1.824282         YES             Signals
# 95      -1.649410         YES            Graffiti
# 96      72.372431         YES    Field Operations
# 97      -1.945706         YES  Signs and Markings
# 98    -998.989479         YES    Field Operations
# 99       1.484549         YES    Field Operations
#
#                               service_request_type    SLA_days case_status  \
# 0                                     Stray Animal  999.000000      Closed
# 1                           Removal Of Obstruction    4.322222      Closed
# 2                           Removal Of Obstruction    4.320729      Closed
# 3                       Front Or Side Yard Parking   16.291887      Closed
# 4                         Animal Cruelty(Critical)    0.125000      Closed
# 5               Traffic Signal Ops and Maintenance   30.084468      Closed
# 6                       Front Or Side Yard Parking   16.064294      Closed
# 7                       Front Or Side Yard Parking   16.063796      Closed
# 8                Right Of Way/Sidewalk Obstruction   16.063333      Closed
# 9                       Front Or Side Yard Parking   16.062859      Closed
# 10                      Front Or Side Yard Parking   16.062373      Closed
# 11               Right Of Way/Sidewalk Obstruction   16.061042      Closed
# 12                      Front Or Side Yard Parking   16.060590      Closed
# 13                      Front Or Side Yard Parking   16.060116      Closed
# 14               Right Of Way/Sidewalk Obstruction   16.059537      Closed
# 15                      Front Or Side Yard Parking   16.059074      Closed
# 16                      Front Or Side Yard Parking   16.058646      Closed
# 17               Right Of Way/Sidewalk Obstruction   16.058194      Closed
# 18                      Front Or Side Yard Parking   16.057755      Closed
# 19                      Front Or Side Yard Parking   16.057338      Closed
# 20               Right Of Way/Sidewalk Obstruction   16.056910      Closed
# 21                      Front Or Side Yard Parking   16.056435      Closed
# 22                      Front Or Side Yard Parking   16.055949      Closed
# 23               Right Of Way/Sidewalk Obstruction   16.055498      Closed
# 24                      Front Or Side Yard Parking   16.055000      Closed
# 25                      Front Or Side Yard Parking   16.054560      Closed
# 26               Right Of Way/Sidewalk Obstruction   16.054063      Closed
# 27                      Front Or Side Yard Parking   16.053657      Closed
# 28                      Front Or Side Yard Parking   16.053206      Closed
# 29               Right Of Way/Sidewalk Obstruction   16.052801      Closed
# ..                                             ...         ...         ...
# 70                                    Stray Animal  999.000000      Closed
# 71                         Trapped/Confined Animal    0.500000      Closed
# 72                                    Stray Animal  999.000000      Closed
# 73                         Trapped/Confined Animal    0.500000      Closed
# 74                                  Animal Neglect    5.000000      Closed
# 75                                  Animal Neglect    5.000000      Closed
# 76                                  Animal Neglect    5.000000      Closed
# 77                       Water Ponding or Standing   43.892558      Closed
# 78                                  Animal Neglect    5.000000      Closed
# 79                               Dead Animal - Cat    2.000000      Closed
# 80                                    Stray Animal  999.000000      Closed
# 81                     Aggressive Animal(Critical)    0.500000      Closed
# 82                               Dead Animal - Dog    2.000000      Closed
# 83                        Animal Cruelty(Critical)    0.125000      Closed
# 84                               Dead Animal - Dog    2.000000      Closed
# 85                 Aggressive Animal(Non-Critical)    5.000000      Closed
# 86                                  Animal Neglect    5.000000      Closed
# 87                 Aggressive Animal(Non-Critical)    5.000000      Closed
# 88                                  Animal Neglect    5.000000      Closed
# 89                         Trapped/Confined Animal    0.500000      Closed
# 90                                    Stray Animal  999.000000      Closed
# 91                                  Animal Neglect    5.000000      Closed
# 92                                    Stray Animal  999.000000      Closed
# 93                      Front Or Side Yard Parking   15.850845      Closed
# 94  Traffic Signal Ops and Maintenance - Emergency    1.846817      Closed
# 95                        Graffiti Public Property    2.845775      Closed
# 96                                  Animal Neglect    5.000000      Closed
# 97              Stop/Yield Sign Down/Missing/Faded    2.838646      Closed
# 98                                    Stray Animal  999.000000      Closed
# 99                         Trapped/Confined Animal    0.500000      Closed
#
#    source_id                           request_address  council_district  \
# 0   svcCRMLS      2315  EL PASO ST, San Antonio, 78207                 5
# 1   svcCRMSS       2215  GOLIAD RD, San Antonio, 78223                 3
# 2   svcCRMSS     102  PALFREY ST W, San Antonio, 78223                 3
# 3   svcCRMSS      114  LA GARDE ST, San Antonio, 78223                 3
# 4   svcCRMSS     734  CLEARVIEW DR, San Antonio, 78228                 7
# 5   svcCRMSS                  BANDERA RD and BRESNAHAN                 7
# 6   svcCRMSS  10133  FIGARO CANYON, San Antonio, 78251                 4
# 7   svcCRMSS  10133  FIGARO CANYON, San Antonio, 78251                 4
# 8   svcCRMSS  10133  FIGARO CANYON, San Antonio, 78251                 4
# 9   svcCRMSS  10133  FIGARO CANYON, San Antonio, 78251                 4
# 10  svcCRMSS  10133  FIGARO CANYON, San Antonio, 78251                 4
# 11  svcCRMSS  10133  FIGARO CANYON, San Antonio, 78251                 4
# 12  svcCRMSS    10129  BOXING PASS, San Antonio, 78251                 4
# 13  svcCRMSS    10129  BOXING PASS, San Antonio, 78251                 4
# 14  svcCRMSS    10129  BOXING PASS, San Antonio, 78251                 4
# 15  svcCRMSS     834  BARREL POINT, San Antonio, 78251                 4
# 16  svcCRMSS     834  BARREL POINT, San Antonio, 78251                 4
# 17  svcCRMSS     834  BARREL POINT, San Antonio, 78251                 4
# 18  svcCRMSS     834  BARREL POINT, San Antonio, 78251                 4
# 19  svcCRMSS     834  BARREL POINT, San Antonio, 78251                 4
# 20  svcCRMSS     834  BARREL POINT, San Antonio, 78251                 4
# 21  svcCRMSS     834  BARREL POINT, San Antonio, 78251                 4
# 22  svcCRMSS     834  BARREL POINT, San Antonio, 78251                 4
# 23  svcCRMSS     834  BARREL POINT, San Antonio, 78251                 4
# 24  svcCRMSS     837  BARREL POINT, San Antonio, 78251                 4
# 25  svcCRMSS     837  BARREL POINT, San Antonio, 78251                 4
# 26  svcCRMSS     837  BARREL POINT, San Antonio, 78251                 4
# 27  svcCRMSS     837  BARREL POINT, San Antonio, 78251                 4
# 28  svcCRMSS     837  BARREL POINT, San Antonio, 78251                 4
# 29  svcCRMSS     837  BARREL POINT, San Antonio, 78251                 4
# ..       ...                                       ...               ...
# 70   ns16326                    CULEBRA RD and IH 10 W                 1
# 71   ns16326      516  FLORES ST S, San Antonio, 78204                 1
# 72   ns16326        146  SURFRIDER, San Antonio, 78242                 4
# 73    139344    5926  SMOKY QUARTZ, San Antonio, 78222                 2
# 74   ns16326           9010  SEINE, San Antonio, 78250                 6
# 75    139344      3238  MISSION RD, San Antonio, 78214                 3
# 76   ns16326   8211  ACADEMIC POST, San Antonio, 78250                 6
# 77  svcCRMSS                RAWHIDE LANE and REMUDA DR                 6
# 78    139344         129  SOUTHWAY, San Antonio, 78225                 5
# 79    139344        5013  EVERS RD, San Antonio, 78228                 7
# 80   ns16326           NEW BRNFLS S and PECAN VALLEY D                 3
# 81  svcCRMSS  9898  COLONNADE BLVD, San Antonio, 78230                 8
# 82    139344    603  SAN EDUARDO S, San Antonio, 78237                 5
# 83  svcCRMSS                PRENTISS DR and PRESLEY DR                 7
# 84    139344    422  SAN HORACIO S, San Antonio, 78237                 5
# 85    139344            SAN FERNANDO and SAN HORACIO S                 5
# 86   ns16326        1915  LAMAR ST, San Antonio, 78202                 2
# 87    139344          812  MONTANA, San Antonio, 78203                 2
# 88    139344          819  MONTANA, San Antonio, 78203                 2
# 89   ns16326         1031  VERMONT, San Antonio, 78211                 5
# 90    139344     110  HEFLIN COURT, San Antonio, 78210                 3
# 91    139344         145  ODELL ST, San Antonio, 78212                 1
# 92   ns16326    1500  HARLAN AVE W, San Antonio, 78211                 5
# 93  svcCRMSS     1514  MORNING SUN, San Antonio, 78228                 7
# 94   ns16326            BUENA VISTA ST and S ZARZAMORA                 5
# 95  svcCRMLS    609  DEWEY PLACE E, San Antonio, 78212                 1
# 96    139344        3026  WEIR AVE, San Antonio, 78226                 5
# 97  svcCRMSS          MAGNOLIA AVE W and SAN PEDRO AVE                 1
# 98    139344   1843  CRAIG PLACE W, San Antonio, 78201                 7
# 99   ns16326           241  BONAIR, San Antonio, 78222                 3
#
#    source_id    source_username       dept_division  \
# 0   svcCRMLS           svcCRMLS    Field Operations
# 1   svcCRMSS           svcCRMSS         Storm Water
# 2   svcCRMSS           svcCRMSS         Storm Water
# 3   svcCRMSS           svcCRMSS    Code Enforcement
# 4   svcCRMSS           svcCRMSS    Field Operations
# 5   svcCRMSS           svcCRMSS             Signals
# 6   svcCRMSS           svcCRMSS    Code Enforcement
# 7   svcCRMSS           svcCRMSS    Code Enforcement
# 8   svcCRMSS           svcCRMSS    Code Enforcement
# 9   svcCRMSS           svcCRMSS    Code Enforcement
# 10  svcCRMSS           svcCRMSS    Code Enforcement
# 11  svcCRMSS           svcCRMSS    Code Enforcement
# 12  svcCRMSS           svcCRMSS    Code Enforcement
# 13  svcCRMSS           svcCRMSS    Code Enforcement
# 14  svcCRMSS           svcCRMSS    Code Enforcement
# 15  svcCRMSS           svcCRMSS    Code Enforcement
# 16  svcCRMSS           svcCRMSS    Code Enforcement
# 17  svcCRMSS           svcCRMSS    Code Enforcement
# 18  svcCRMSS           svcCRMSS    Code Enforcement
# 19  svcCRMSS           svcCRMSS    Code Enforcement
# 20  svcCRMSS           svcCRMSS    Code Enforcement
# 21  svcCRMSS           svcCRMSS    Code Enforcement
# 22  svcCRMSS           svcCRMSS    Code Enforcement
# 23  svcCRMSS           svcCRMSS    Code Enforcement
# 24  svcCRMSS           svcCRMSS    Code Enforcement
# 25  svcCRMSS           svcCRMSS    Code Enforcement
# 26  svcCRMSS           svcCRMSS    Code Enforcement
# 27  svcCRMSS           svcCRMSS    Code Enforcement
# 28  svcCRMSS           svcCRMSS    Code Enforcement
# 29  svcCRMSS           svcCRMSS    Code Enforcement
# ..       ...                ...                 ...
# 70   ns16326  Norma K. Sotoodeh    Field Operations
# 71   ns16326  Norma K. Sotoodeh    Field Operations
# 72   ns16326  Norma K. Sotoodeh    Field Operations
# 73    139344       Isis Mendoza    Field Operations
# 74   ns16326  Norma K. Sotoodeh    Field Operations
# 75    139344       Isis Mendoza    Field Operations
# 76   ns16326  Norma K. Sotoodeh    Field Operations
# 77  svcCRMSS           svcCRMSS             Streets
# 78    139344       Isis Mendoza    Field Operations
# 79    139344       Isis Mendoza       Miscellaneous
# 80   ns16326  Norma K. Sotoodeh    Field Operations
# 81  svcCRMSS           svcCRMSS    Field Operations
# 82    139344       Isis Mendoza       Miscellaneous
# 83  svcCRMSS           svcCRMSS    Field Operations
# 84    139344       Isis Mendoza       Miscellaneous
# 85    139344       Isis Mendoza    Field Operations
# 86   ns16326  Norma K. Sotoodeh    Field Operations
# 87    139344       Isis Mendoza    Field Operations
# 88    139344       Isis Mendoza    Field Operations
# 89   ns16326  Norma K. Sotoodeh    Field Operations
# 90    139344       Isis Mendoza    Field Operations
# 91    139344       Isis Mendoza    Field Operations
# 92   ns16326  Norma K. Sotoodeh    Field Operations
# 93  svcCRMSS           svcCRMSS    Code Enforcement
# 94   ns16326  Norma K. Sotoodeh             Signals
# 95  svcCRMLS           svcCRMLS            Graffiti
# 96    139344       Isis Mendoza    Field Operations
# 97  svcCRMSS           svcCRMSS  Signs and Markings
# 98    139344       Isis Mendoza    Field Operations
# 99   ns16326  Norma K. Sotoodeh    Field Operations
#
#                     dept_name    standardized_dept_name dept_subject_to_SLA
# 0        Animal Care Services      Animal Care Services                 YES
# 1    Trans & Cap Improvements  Trans & Cap Improvements                 YES
# 2    Trans & Cap Improvements  Trans & Cap Improvements                 YES
# 3   Code Enforcement Services      DSD/Code Enforcement                 YES
# 4        Animal Care Services      Animal Care Services                 YES
# 5    Trans & Cap Improvements  Trans & Cap Improvements                 YES
# 6   Code Enforcement Services      DSD/Code Enforcement                 YES
# 7   Code Enforcement Services      DSD/Code Enforcement                 YES
# 8   Code Enforcement Services      DSD/Code Enforcement                 YES
# 9   Code Enforcement Services      DSD/Code Enforcement                 YES
# 10  Code Enforcement Services      DSD/Code Enforcement                 YES
# 11  Code Enforcement Services      DSD/Code Enforcement                 YES
# 12  Code Enforcement Services      DSD/Code Enforcement                 YES
# 13  Code Enforcement Services      DSD/Code Enforcement                 YES
# 14  Code Enforcement Services      DSD/Code Enforcement                 YES
# 15  Code Enforcement Services      DSD/Code Enforcement                 YES
# 16  Code Enforcement Services      DSD/Code Enforcement                 YES
# 17  Code Enforcement Services      DSD/Code Enforcement                 YES
# 18  Code Enforcement Services      DSD/Code Enforcement                 YES
# 19  Code Enforcement Services      DSD/Code Enforcement                 YES
# 20  Code Enforcement Services      DSD/Code Enforcement                 YES
# 21  Code Enforcement Services      DSD/Code Enforcement                 YES
# 22  Code Enforcement Services      DSD/Code Enforcement                 YES
# 23  Code Enforcement Services      DSD/Code Enforcement                 YES
# 24  Code Enforcement Services      DSD/Code Enforcement                 YES
# 25  Code Enforcement Services      DSD/Code Enforcement                 YES
# 26  Code Enforcement Services      DSD/Code Enforcement                 YES
# 27  Code Enforcement Services      DSD/Code Enforcement                 YES
# 28  Code Enforcement Services      DSD/Code Enforcement                 YES
# 29  Code Enforcement Services      DSD/Code Enforcement                 YES
# ..                        ...                       ...                 ...
# 70       Animal Care Services      Animal Care Services                 YES
# 71       Animal Care Services      Animal Care Services                 YES
# 72       Animal Care Services      Animal Care Services                 YES
# 73       Animal Care Services      Animal Care Services                 YES
# 74       Animal Care Services      Animal Care Services                 YES
# 75       Animal Care Services      Animal Care Services                 YES
# 76       Animal Care Services      Animal Care Services                 YES
# 77   Trans & Cap Improvements  Trans & Cap Improvements                 YES
# 78       Animal Care Services      Animal Care Services                 YES
# 79     Solid Waste Management               Solid Waste                 YES
# 80       Animal Care Services      Animal Care Services                 YES
# 81       Animal Care Services      Animal Care Services                 YES
# 82     Solid Waste Management               Solid Waste                 YES
# 83       Animal Care Services      Animal Care Services                 YES
# 84     Solid Waste Management               Solid Waste                 YES
# 85       Animal Care Services      Animal Care Services                 YES
# 86       Animal Care Services      Animal Care Services                 YES
# 87       Animal Care Services      Animal Care Services                 YES
# 88       Animal Care Services      Animal Care Services                 YES
# 89       Animal Care Services      Animal Care Services                 YES
# 90       Animal Care Services      Animal Care Services                 YES
# 91       Animal Care Services      Animal Care Services                 YES
# 92       Animal Care Services      Animal Care Services                 YES
# 93  Code Enforcement Services      DSD/Code Enforcement                 YES
# 94   Trans & Cap Improvements  Trans & Cap Improvements                 YES
# 95  Code Enforcement Services      DSD/Code Enforcement                 YES
# 96       Animal Care Services      Animal Care Services                 YES
# 97   Trans & Cap Improvements  Trans & Cap Improvements                 YES
# 98       Animal Care Services      Animal Care Services                 YES
# 99       Animal Care Services      Animal Care Services                 YES
#
# [100 rows x 20 columns]

# %% [markdown]
# ##### Are there any cases that do not have a request source?
# No

# %%
(df.join(source_df, 
         df.source_id == source_df.source_id, 
         'left')
 .join(dept_df, 
       df.dept_division == dept_df.dept_division, 
       'left')).where(F.isnull(df.source_id)).show()
# Out:
# +-------+----------------+----------------+------------+---------+-------------+-----------+-------------+--------------------+--------+-----------+---------+---------------+----------------+---------+---------------+-------------+---------+----------------------+-------------------+
# |case_id|case_opened_date|case_closed_date|SLA_due_date|case_late|num_days_late|case_closed|dept_division|service_request_type|SLA_days|case_status|source_id|request_address|council_district|source_id|source_username|dept_division|dept_name|standardized_dept_name|dept_subject_to_SLA|
# +-------+----------------+----------------+------------+---------+-------------+-----------+-------------+--------------------+--------+-----------+---------+---------------+----------------+---------+---------------+-------------+---------+----------------------+-------------------+
# +-------+----------------+----------------+------------+---------+-------------+-----------+-------------+--------------------+--------+-----------+---------+---------------+----------------+---------+---------------+-------------+---------+----------------------+-------------------+

# %% [markdown]
# ## Part 4
# 1. Who are the top 10 service request types in terms of number of requests?
# 1. Who are the top 10 service request types in terms of average days late?
# 1. Does number of days late depend on department?
# 1. How do number of days late depend on department division and request type?

# %%
full = (df.join(source_df, 
         'source_id', 
         'left')
        .join(dept_df, 
       'dept_division', 
       'left'))

# %% [markdown]
# ##### What are the top 10 service request types in terms of number of requests?

# %%
full.groupBy(full.service_request_type).count().sort('count', ascending=False).show(10, truncate=False)
# Out:
# +--------------------------------+-----+
# |service_request_type            |count|
# +--------------------------------+-----+
# |No Pickup                       |89210|
# |Overgrown Yard/Trash            |66403|
# |Bandit Signs                    |32968|
# |Damaged Cart                    |31163|
# |Front Or Side Yard Parking      |28920|
# |Stray Animal                    |27361|
# |Aggressive Animal(Non-Critical) |25492|
# |Cart Exchange Request           |22608|
# |Junk Vehicle On Private Property|21649|
# |Pot Hole Repair                 |20827|
# +--------------------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ##### What are the top 10 service request types in terms of average days late?

# %%
(full.select(full.service_request_type,
             full.num_days_late)
 .groupBy(full.service_request_type)
 .avg('num_days_late')
 .sort('avg(num_days_late)', ascending=False)
 .show(10, truncate=False))
# Out:
# +--------------------------------------+------------------+
# |service_request_type                  |avg(num_days_late)|
# +--------------------------------------+------------------+
# |Zoning: Junk Yards                    |175.95636210420932|
# |Labeling for Used Mattress            |162.43032902285717|
# |Record Keeping of Used Mattresses     |153.99724039428568|
# |Signage Requied for Sale of Used Mattr|151.63868055333333|
# |Storage of Used Mattress              |142.112556415     |
# |Zoning: Recycle Yard                  |135.9285161247979 |
# |Donation Container Enforcement        |131.75610506358706|
# |License Requied Used Mattress Sales   |128.79828704142858|
# |Traffic Signal Graffiti               |101.79846062200002|
# |Complaint                             |72.87050230311685 |
# +--------------------------------------+------------------+
# only showing top 10 rows

# %% [markdown]
# ##### Does number of days late depend on department?

# %%
(full.select(full.dept_name, full.num_days_late)
 .groupBy('dept_name')
 .avg('num_days_late')
 .show())
# Out:
# +--------------------+-------------------+
# |           dept_name| avg(num_days_late)|
# +--------------------+-------------------+
# |Animal Care Services| -226.5178394055038|
# |                null|  135.9285161247979|
# |Solid Waste Manag...|-2.2000575136721308|
# |Development Services| 13.433724555869683|
# |Trans & Cap Impro...| -20.61283735405259|
# |    Customer Service| 59.737091496300735|
# |        Metro Health| -4.911766979607019|
# |Parks and Recreation| -5.251521960055141|
# |Code Enforcement ...| -38.70133068329481|
# |        City Council|               null|
# +--------------------+-------------------+

# %% [markdown]
# ##### How do number of days late depend on department division and request type?

# %%
(full.select(full.dept_division, full.num_days_late, full.service_request_type)
 .groupBy(['dept_division', 'service_request_type'])
 .avg('num_days_late')
 .orderBy(['dept_division', 'service_request_type'])
 .show())
# Out:
# +---------------+--------------------+--------------------+
# |  dept_division|service_request_type|  avg(num_days_late)|
# +---------------+--------------------+--------------------+
# |311 Call Center|           Complaint|   72.87050230311685|
# |311 Call Center|          Compliment|   -8.03018814654584|
# |          Brush|Brush - Out of Cy...|  -4.316590201619218|
# |          Brush|Brush / Bulky Mis...| -3.0420300215330762|
# |          Brush|Brush Missed Pick up|  -5.879397585624517|
# |          Brush|     Brush No Notice|  -2.938521994696245|
# |          Brush|Brush Partial Pic...|  -5.288008891714286|
# |          Brush|Brush Property Da...|  -4.930477772768818|
# |          Brush|Brush-non Complia...| -2.7342875787021272|
# |          Brush|Brush_Received In...|  -7.224293981400001|
# |          Brush| Bulk Missed Pick up|  -3.447529808084811|
# |          Brush|Bulk Partial Pick Up|-0.45940326771153916|
# |          Brush|      Bulk no Notice|  -2.998967278570979|
# |          Brush|Bulk-non Complian...| -1.6289843748571424|
# |          Brush|Bulk_Received Inv...|        -4.458275463|
# |          Brush|Illegal Dumping (...| -1.8100113831090217|
# |          Brush|        Storm Damage| -11.024134961740991|
# |Clean and Green|Brush/Debris Coll...|  -0.672145120384031|
# |Clean and Green|Indoor Janitorial...|       -2.0209759425|
# |Clean and Green|Landscape Mainten...|  -7.204356892564459|
# +---------------+--------------------+--------------------+
# only showing top 20 rows
